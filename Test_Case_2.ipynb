# %%
from run import run_TransitionHunter

# %% [markdown]
# # Test Case 2
# ### Successfully identify and report negative result.
# #### Can TransitionHunter confirm there was no transition in the evolution of SN 2024ggi?

# %%
run_TransitionHunter('2024ggi', searchWiseRep=True)
# Out:
# ...
# www.wiserep.org/system/files/uploaded/general/2024ggi_2024-04-11_23-31-08.500_SALT_RSS_None.fits
# www.wiserep.org/system/files/uploaded/general/2024ggi_2024-04-11_23-48-04.390_Gemini-S_GMOS-S_None.fits
# www.wiserep.org/system/files/uploaded/general/2024ggi_2024-04-12_12-51-32.999_FTS_FLOYDS-S_None.fits
# www.wiserep.org/system/files/uploaded/general/2024ggi_2024-04-13_05-15-11.336_Bok_BC-Bok_None.fits
# www.wiserep.org/system/files/uploaded/general/2024ggi_2024-04-14_05-26-54.657_Bok_BC-Bok_None.fits
# www.wiserep.org/system/files/uploaded/general/2024ggi_2024-04-15_04-59-09.810_Bok_BC-Bok_None.fits
# www.wiserep.org/system/files/uploaded/general/2024ggi_2024-04-16_06-46-04.938_FTN_FLOYDS-N_None.fits
# www.wiserep.org/system/files/uploaded/general/2024ggi_2024-04-17_23-13-39.750_SALT_RSS_None.fits
# www.wiserep.org/system/files/uploaded/general/2024ggi_2024-04-20_06-00-17.176_FTN_FLOYDS-N_None.fits
# ...

# %% [markdown]
# ## Success!
# #### We've reported a transition in subtype but NOT in type.
# The code is relatively confident that a transition has occured, but succesffully reports a consistent type II SNe.
# This is consistent with the behavior of SN 2024ggi as reported in literature from a Ib --> II.
# Caveat: The subtype II-flash can be degenerate with IIP so although a transition was reported this information may be misleading. However, some subclasses do note significant physical changes in a SN, so this is the ideal report.
