# %%
from run import run_TransitionHunter

# %% [markdown]
# # Test Case 1
# ### Successfully identify and report the transition of SN 2014C from a Ib to a IIn?
# (Milisavljevic et al. 2015; ADS: https://ui.adsabs.harvard.edu/abs/2015ApJ...815..120M/abstract)

# %%
run_TransitionHunter('2014C', searchWiseRep=True)
# Out:
# ...
# www.wiserep.org/system/files/uploaded/Asiago/2014C_2014-01-08_18-46-13_Ekar_AFOSC_Asiago.fits
# | IAU Name   | Obj type   |   Redshift | Obs-date (UT)          | Tel / Inst           | Spectrum ascii File                                      | Spectrum fits File                               |
# |:-----------|:-----------|-----------:|:-----------------------|:---------------------|:---------------------------------------------------------|:-------------------------------------------------|
# | SN 2014C   | SN Ib      |   0.002722 | 2014-01-05 12:43:12.00 | Lijiang-2.4m / YFOSC | 2014C_2456663.030_Lijiang-2.4m_YFOSC_None.dat            | nan                                              |
# | SN 2014C   | SN Ib      |   0.002722 | 2014-01-06 12:14:24.00 | Lijiang-2.4m / YFOSC | 2014C_2456664.010_Lijiang-2.4m_YFOSC_None.dat            | nan                                              |
# ...

# %% [markdown]
# ## Success!
# #### We've succesfully reported a transition.
# The code is relatively confident that a transition has occured, with 2 relativel high confidence classifications.
# This is consistent with the behavior of SN 2014C as reported in literature from a Ib --> II.
# Caveat: Given the dataset we miss the nuance that it in fact transitions to a IIn not a IIP, but that weakness is accurately reflected in SNID-SAGE's match_quality and subtype confidence score for that classification (Medium and Low respectively).
