# %% [markdown]
# ### Test Data Import

# %% [markdown]
# This notebook will download and organize spectra for the SN 2019odp

# %%
import os
import glob
import tabulate
import pandas as pd
from io import StringIO
from astropy.io import fits
import numpy as np
import astropy
from wiserep_api import download_target_spectra
import spectra

# %%
# sn = '2019odp'
# sn = '2024ggi'
sn = '2014c'

# %%
spectra.get_WISeREP_spectra(sn)
# Out:
# ...
# www.wiserep.org/system/files/uploaded/Asiago/2014C_2014-01-08_18-46-13_Ekar_AFOSC_Asiago.fits
# | IAU Name   | Obj type   |   Redshift | Obs-date (UT)          | Tel / Inst           | Spectrum ascii File                                      | Spectrum fits File                               |
# |:-----------|:-----------|-----------:|:-----------------------|:---------------------|:---------------------------------------------------------|:-------------------------------------------------|
# | SN 2014C   | SN Ib      |   0.002722 | 2014-01-05 12:43:12.00 | Lijiang-2.4m / YFOSC | 2014C_2456663.030_Lijiang-2.4m_YFOSC_None.dat            | nan                                              |
# | SN 2014C   | SN Ib      |   0.002722 | 2014-01-06 12:14:24.00 | Lijiang-2.4m / YFOSC | 2014C_2456664.010_Lijiang-2.4m_YFOSC_None.dat            | nan                                              |
# ...

# %%
spectra.organize_imports(sn, searchWiseRep=True)
# Out:
# Organizing files...
#
# Copying all files into a /raw directory...
#
# Removing duplicate spectra...
#
#    keeping: 2014C_2014-01-08_18-46-13_Ekar_AFOSC_Asiago.fits
#
#    removing: 2014C_2014-01-08_18-46-13_Ekar_AFOSC_Asiago.ascii

# %% [markdown]
# You should notice a new directory /raw, where your data imports have been stored for posterity, and the /spectra directory where unique epochs of spectra are listed.

# %%
# sn2 = '2008D'

# %%
spectra.get_WISeREP_spectra(sn2)
# Out:
# ...
# | IAU Name   | Obj type   |   Redshift | Obs-date (UT)          | Tel / Inst             | Spectrum ascii File                                         |   Spectrum fits File |
# |:-----------|:-----------|-----------:|:-----------------------|:-----------------------|:------------------------------------------------------------|---------------------:|
# | SN 2008D   | SN Ib      |   0.006521 | 2008-01-10 00:00:00.00 | VLT-UT1 / FORS2        | 2008D_2008-01-10_00-00-00_VLT-UT1_FORS2_SUSPECT.dat         |                  nan |
# | SN 2008D   | SN Ib      |   0.006521 | 2008-01-11 00:00:00.00 | MMT / MMT-Blue         | SN2008D_2008-01-11_00-00-00_MMT_MMT-Blue_None.flm           |                  nan |
# | SN 2008D   | SN Ib      |   0.006521 | 2008-01-11 00:00:00.00 | Gemini-S / GMOS-S      | SN2008D_2008-01-11_00-00-00_Gemini-S_GMOS-S_None.flm        |                  nan |
# ...

# %%
spectra.organize_imports(sn2, searchWiseRep=True)
# Out:
# Organizing files...
#
# Copying all files into a /raw directory...
