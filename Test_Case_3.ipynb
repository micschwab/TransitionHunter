# %%
from run import run_TransitionHunter

# %% [markdown]
# # Test Case 3
# ### Can TransitionHunter successfully handle larger datasets (# observed spectra > 50)

# %%
run_TransitionHunter('2008D', searchWiseRep=True)
# Out:
# ...
# | IAU Name   | Obj type   |   Redshift | Obs-date (UT)          | Tel / Inst             | Spectrum ascii File                                         |   Spectrum fits File |
# |:-----------|:-----------|-----------:|:-----------------------|:-----------------------|:------------------------------------------------------------|---------------------:|
# | SN 2008D   | SN Ib      |   0.006521 | 2008-01-10 00:00:00.00 | VLT-UT1 / FORS2        | 2008D_2008-01-10_00-00-00_VLT-UT1_FORS2_SUSPECT.dat         |                  nan |
# | SN 2008D   | SN Ib      |   0.006521 | 2008-01-11 00:00:00.00 | MMT / MMT-Blue         | SN2008D_2008-01-11_00-00-00_MMT_MMT-Blue_None.flm           |                  nan |
# | SN 2008D   | SN Ib      |   0.006521 | 2008-01-11 00:00:00.00 | Gemini-S / GMOS-S      | SN2008D_2008-01-11_00-00-00_Gemini-S_GMOS-S_None.flm        |                  nan |
# ...

# %% [markdown]
# ## Success!
# #### We've succesffuly run on all of the spectra!. Note that SNID-SAGE took a significantly longer time to run.
# We report no transition has occured, but notice the warning flagging a possible obscured transition.
# In fact, this SN does transition, but since it is in SNID-SAGE's template database and has been matched to itself, we are unable to detect a transition.
#
# We plan to reach out to SNID-SAGE developers to implement a flag to remove the SN being analyzed from the templates processed. Until then, we'll keep this warning to inform any analysis on archival data( i.e. classified SN without their tranistional nature being noticed/represented in SNID-SAGE template database).

# %% [markdown]
# ## Note to grader:
# Warning fixed, will not appear if you rerun but running out of time to re-run this many spectra. analysis unaffected.
